# %% [markdown]
# # Hands-On Machine Learning: Logistic Regression with Python and Scikit-Learn

# %% [markdown]
# https://www.youtube.com/watch?app=desktop&v=aL21Y-u0SRs

# %%
import pandas as pd
